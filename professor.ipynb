# %%
import random

# generate_integer(x)


def main():
    level = get_level()
    result = 0
    if level == 1:
        for _ in range(10):
            c = 0
            a = generate_integer(level)
            b = generate_integer(level)
            z = int(a + b)
            while True:
                try:
                    ans = int(input(f"{a} + {b} = "))
                    if c == 2:
                        print("EEE")
                        print(f"{a} + {b} = {z}")
                        break
                    else:
                        if ans == z:
                            result += 1
                            break
                        else:
                            print("EEE")
                            c += 1
                except ValueError:
                    print("EEE")
                    pass
        print(f"Score: {result}")

    elif level == 2:
        for _ in range(10):
            c = 0
            a = generate_integer(level)
            b = generate_integer(level)
            z = int(a + b)
            while True:
                try:
                    ans = int(input(f"{a} + {b} = "))
                    if c == 2:
                        print("EEE")
                        print(f"{a} + {b} = {z}")
                        break
                    else:
                        if ans == z:
                            result += 1
                            break
                        else:
                            print("EEE")
                            c += 1
                except ValueError:
                    print("EEE")
                    pass
        print(f"Score: {result}")

    else:
        for _ in range(10):
            c = 0
            a = generate_integer(level)
            b = generate_integer(level)
            z = int(a + b)
            while True:
                try:
                    ans = int(input(f"{a} + {b} = "))
                    if c == 2:
                        print("EEE")
                        print(f"{a} + {b} = {z}")
                        break
                    else:
                        if ans == z:
                            result += 1
                            break
                        else:
                            print("EEE")
                            c += 1
                except ValueError:
                    print("EEE")
                    pass
        print(f"Score: {result}")


def get_level():
    while True:
        i = input("Level: ")
        if i.isnumeric() and 0 < int(i) < 4:
            i = int(i)
            # generate_integer(i)
            return i
        else:
            pass


def generate_integer(level):
    if level == 1:
        return random.randrange(0, 10)
    elif level == 2:
        return random.randrange(10, 100)
    elif level == 3:
        return random.randrange(100, 1000)
    else:
        raise ValueError


if __name__ == "__main__":
    main()
